# %% [markdown]
# <a href="https://colab.research.google.com/github/ngzhiwei517/Machine_Learning_Self-Learn/blob/main/Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/nyc_weather.csv")

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.isna().sum()
# Out:
# EST                      0
# Temperature              0
# DewPoint                 0
# Humidity                 0
# Sea Level PressureIn     0
# VisibilityMiles          0
# WindSpeedMPH             3
# PrecipitationIn          0
# CloudCover               0
# Events                  22
# WindDirDegrees           0
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
weather_df=pd.DataFrame(weather_data)
weather_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
rows,col=weather_df.shape

# %%
rows,col
# Out:
# (6, 4)

# %% [markdown]
# Print from row 2 to 5 (not inclusive)

# %%
weather_df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %% [markdown]
# # Columns

# %%
weather_df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
weather_df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
weather_df[['day','temperature']]
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 2  1/3/2017           28
# 3  1/4/2017           24
# 4  1/5/2017           32
# 5  1/6/2017           31

# %% [markdown]
# # Operations on Data Frame

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df[df['Temperature']>32]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# ...

# %%
type(df['Temperature'])
# Out:
# pandas.core.series.Series

# %% [markdown]
#  # Operation on data frame

# %%
weather_df['temperature'].max() #mean/std
# Out:
# 35

# %%
weather_df[weather_df.temperature>30]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
weather_df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
weather_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
weather_df[weather_df.temperature==weather_df.temperature.max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df.Temperature.std()
# Out:
# 7.639315400279415

# %% [markdown]
# # Set index
#
# Advantage is that we can select row by using day instead

# %%
weather_df.set_index('day')
# Out:
#           temperature  windspeed  event  temp_celsius
# day
# 1/1/2017           32          6   Rain      0.000000
# 1/2/2017           35          7  Sunny      1.666667
# 1/3/2017           28          2  Snowy     -2.222222
# 1/4/2017           24          7  Snowy     -4.444444
# 1/5/2017           32          4   Rain      0.000000
# 1/6/2017           31          2  Sunny     -0.555556

# %%
weather_df.iloc[4]
# Out:
# day             1/5/2017
# temperature           32
# windspeed              4
# event               Rain
# temp_celsius         0.0
# Name: 4, dtype: object

# %%
weather_df=weather_df.set_index('day')

# %%
weather_df
# Out:
#           temperature  windspeed  event  temp_celsius
# day
# 1/1/2017           32          6   Rain      0.000000
# 1/2/2017           35          7  Sunny      1.666667
# 1/3/2017           28          2  Snowy     -2.222222
# 1/4/2017           24          7  Snowy     -4.444444
# 1/5/2017           32          4   Rain      0.000000
# 1/6/2017           31          2  Sunny     -0.555556

# %%
weather_df.loc['1/2/2017']
# Out:
# temperature           35
# windspeed              7
# event              Sunny
# temp_celsius    1.666667
# Name: 1/2/2017, dtype: object

# %% [markdown]
# ---
#
#
# 📝 PANDAS PRACTICE
#
# Q1️⃣: Select all rows where event = "Snow"

# %%
weather_df[weather_df['event']=='Snow']
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow

# %% [markdown]
# ➡️ “From the day column, select only the rows where temperature is the highest.”

# %%
weather_df['day'][weather_df['temperature']==weather_df['temperature'].max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %% [markdown]
# Q3️⃣: Find the day(s) with the highest temperature

# %%
weather_df['day'][weather_df.temperature==weather_df.temperature.max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %% [markdown]
# Q5️⃣: Show only the columns day and event

# %%
weather_df[['day','event']]
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow
# 3  1/4/2017   Snow
# 4  1/5/2017   Rain
# 5  1/6/2017  Sunny

# %% [markdown]
# Print the day and temperature when the temperature is max

# %%
weather_df[['day','temperature']][weather_df.temperature==weather_df.temperature.max()]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %% [markdown]
# Q6️⃣: Count how many days were Rain, Sunny, and Snow

# %%
weather_df.event.value_counts()
# Out:
# event
# Rain     2
# Sunny    2
# Snow     2
# Name: count, dtype: int64

# %%
weather_df.groupby('event')['day'].count()
# Out:
# event
# Rain     2
# Snow     2
# Sunny    2
# Name: day, dtype: int64

# %% [markdown]
# Q7️⃣: Filter rows where temperature is ≥ 30

# %%
weather_df[weather_df.temperature>=30]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# Q9️⃣: Sort by temperature (descending)

# %%
weather_df.sort_values('temperature',ascending=False)
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 0  1/1/2017           32          6   Rain
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow

# %%
weather_df.sort_values(by=['windspeed','temperature'],ascending=[True,False])
# Out:
#         day  temperature  windspeed  event
# 5  1/6/2017           31          2  Sunny
# 2  1/3/2017           28          2   Snow
# 4  1/5/2017           32          4   Rain
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 3  1/4/2017           24          7   Snow

# %% [markdown]
# Q1️⃣1️⃣: Add a new column "temp_celsius"
#
# Formula: °C = (F − 32) × 5/9 (just for practice)

# %%
weather_df['temp_celsius']=(weather_df['temperature']-32)*(5/9)

# %%
weather_df
# Out:
#         day  temperature  windspeed  event  temp_celsius
# 0  1/1/2017           32          6   Rain      0.000000
# 1  1/2/2017           35          7  Sunny      1.666667
# 2  1/3/2017           28          2   Snow     -2.222222
# 3  1/4/2017           24          7   Snow     -4.444444
# 4  1/5/2017           32          4   Rain      0.000000
# 5  1/6/2017           31          2  Sunny     -0.555556

# %%
weather_df['temperature']
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: temperature, dtype: bool

# %% [markdown]
# Q1️⃣4️⃣: Replace all "Snow" with "Snowy"

# %%
weather_df['event']=weather_df['event'].replace('Snow','Snowy')
weather_df
# Out:
#         day  temperature  windspeed  event  temp_celsius
# 0  1/1/2017           32          6   Rain      0.000000
# 1  1/2/2017           35          7  Sunny      1.666667
# 2  1/3/2017           28          2  Snowy     -2.222222
# 3  1/4/2017           24          7  Snowy     -4.444444
# 4  1/5/2017           32          4   Rain      0.000000
# 5  1/6/2017           31          2  Sunny     -0.555556
