# %% [markdown]
# <a href="https://colab.research.google.com/github/ngzhiwei517/Machine_Learning_Self-Learn/blob/main/Grid_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Finding best model and hyper parameter tunning using GridSearchCV

# %%
from sklearn import svm, datasets
iris = datasets.load_iris()

# %%
import pandas as pd
df = pd.DataFrame(iris.data,columns=iris.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df['flower']=iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      flower
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df['flower']=df['flower'].apply(lambda x:iris.target_names[x])
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         flower
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Approach 1: Use train_test_split and manually tune parameters by trial and error

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3)

# %%
from sklearn.svm import  SVC
model=SVC(kernel='rbf',gamma='auto',C=50)
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.9555555555555556

# %% [markdown]
# The score is changing based on our sample

# %% [markdown]
# ## Approach 2: Use K Fold Cross validation

# %%
from sklearn.model_selection import cross_val_score
linear=cross_val_score(SVC(kernel='linear',gamma='auto',C=10),iris.data,iris.target,cv=5)

# %%
import numpy as np
avg_score=np.average(linear)
avg_score
# Out:
# np.float64(0.9733333333333334)

# %%
rbf_10=cross_val_score(SVC(kernel='rbf',gamma='auto',C=10),iris.data,iris.target,cv=5)

# %%
avg_rbf=np.average(rbf_10)
avg_rbf
# Out:
# np.float64(0.9800000000000001)

# %%
rbf_20=cross_val_score(SVC(kernel='rbf',gamma='auto',C=20),iris.data,iris.target,cv=5)

# %%
avg_rbf=np.average(rbf_20)
avg_rbf
# Out:
# np.float64(0.9666666666666668)

# %%
kernel=['rbf','linear']
c_value=[1,10,20]
avg_score={}
for k in kernel:
  for c_v in c_value:
    score=cross_val_score(SVC(kernel=k,gamma='auto',C=c_v),iris.data,iris.target,cv=5)
    avg_score[k+"_"+str(c_v)]=np.average(score)
avg_score
# Out:
# {'rbf_1': np.float64(0.9800000000000001),
#  'rbf_10': np.float64(0.9800000000000001),
#  'rbf_20': np.float64(0.9666666666666668),
#  'linear_1': np.float64(0.9800000000000001),
#  'linear_10': np.float64(0.9733333333333334),
#  'linear_20': np.float64(0.9666666666666666)}

# %% [markdown]
# Find optimal score by using loop but not conveninet if we hv many C, then we need to run the loop many times

# %% [markdown]
# ## Approach 3: Use GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
clf=GridSearchCV(SVC(gamma='auto'),{  #The second parameter of GridSearchCV is the parameter grid
    'C':[1,10,20],
    'kernel':['linear','rbf']
},cv=5,return_train_score=False)
clf.fit(iris.data,iris.target)
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.00239701, 0.00181093, 0.00163851, 0.00167031, 0.00161963,
#         0.00483723]),
#  'std_fit_time': array([1.57703936e-03, 3.33685860e-05, 4.90708298e-05, 1.51408105e-04,
#         4.32092878e-05, 3.27992562e-03]),
#  'mean_score_time': array([0.00132818, 0.00130725, 0.00126953, 0.00128016, 0.00117555,
#         0.00286431]),
#  'std_score_time': array([2.27830399e-04, 4.33405370e-05, 1.19015670e-04, 1.62080983e-04,
#         2.30601920e-05, 1.65427919e-03]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20],
#               mask=[False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['linear', 'rbf', 'linear', 'rbf', 'linear', 'rbf'],
#               mask=[False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'linear'},
#   {'C': 1, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'rbf'}],
#  'split0_test_score': array([0.96666667, 0.96666667, 1.        , 0.96666667, 1.        ,
#         0.96666667]),
#  'split1_test_score': array([1., 1., 1., 1., 1., 1.]),
#  'split2_test_score': array([0.96666667, 0.96666667, 0.9       , 0.96666667, 0.9       ,
#         0.9       ]),
#  'split3_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.96666667, 0.93333333,
#         0.96666667]),
#  'split4_test_score': array([1., 1., 1., 1., 1., 1.]),
#  'mean_test_score': array([0.98      , 0.98      , 0.97333333, 0.98      , 0.96666667,
#         0.96666667]),
#  'std_test_score': array([0.01632993, 0.01632993, 0.03887301, 0.01632993, 0.0421637 ,
#         0.03651484]),
#  'rank_test_score': array([1, 1, 4, 1, 6, 5], dtype=int32)}

# %%
df=pd.DataFrame(clf.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.002397      0.001577         0.001328        0.000228        1
# 1       0.001811      0.000033         0.001307        0.000043        1
# 2       0.001639      0.000049         0.001270        0.000119       10
# 3       0.001670      0.000151         0.001280        0.000162       10
# 4       0.001620      0.000043         0.001176        0.000023       20
# 5       0.004837      0.003280         0.002864        0.001654       20
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 1          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 2       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 3          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 4       linear  {'C': 20, 'kernel': 'linear'}           1.000000
# 5          rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                1.0           0.966667           0.966667                1.0
# 1                1.0           0.966667           0.966667                1.0
# 2                1.0           0.900000           0.966667                1.0
# 3                1.0           0.966667           0.966667                1.0
# 4                1.0           0.900000           0.933333                1.0
# 5                1.0           0.900000           0.966667                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.980000        0.016330                1
# 1         0.980000        0.016330                1
# 2         0.973333        0.038873                4
# 3         0.980000        0.016330                1
# 4         0.966667        0.042164                6
# 5         0.966667        0.036515                5

# %%
df[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1       linear         0.980000
# 1        1          rbf         0.980000
# 2       10       linear         0.973333
# 3       10          rbf         0.980000
# 4       20       linear         0.966667
# 5       20          rbf         0.966667

# %% [markdown]
# # Example (Random Forest)

# %%
clf=GridSearchCV(RandomForestClassifier(),{
    'n_estimator':[100,200,300],

})

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
clf=GridSearchCV(RandomForestClassifier(),{
  'n_estimators':[50,100,150],
  'max_depth':[None,5,10]
})
clf.fit(iris.data,iris.target)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [None, 5, 10],
#                          'n_estimators': [50, 100, 150]})

# %%
clf_results=clf.cv_results_
clf_results
df=pd.DataFrame(clf_results)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.278692      0.042446         0.014113        0.003512
# 1       0.361099      0.084404         0.017268        0.007784
# 2       0.351460      0.058050         0.018911        0.001565
# 3       0.140896      0.028701         0.007798        0.000208
# 4       0.264787      0.020080         0.014100        0.000868
# 5       0.402229      0.018594         0.021701        0.001970
# 6       0.106599      0.034713         0.006474        0.003030
# 7       0.143253      0.004715         0.008308        0.002197
# 8       0.212176      0.003946         0.014114        0.004509
#
#   param_max_depth  param_n_estimators  \
# 0            None                  50
# 1            None                 100
# 2            None                 150
# 3               5                  50
# 4               5                 100
# 5               5                 150
# 6              10                  50
# 7              10                 100
# 8              10                 150
#
#                                      params  split0_test_score  \
# 0   {'max_depth': None, 'n_estimators': 50}           0.966667
# 1  {'max_depth': None, 'n_estimators': 100}           0.966667
# 2  {'max_depth': None, 'n_estimators': 150}           0.966667
# 3      {'max_depth': 5, 'n_estimators': 50}           0.966667
# 4     {'max_depth': 5, 'n_estimators': 100}           0.966667
# 5     {'max_depth': 5, 'n_estimators': 150}           0.966667
# 6     {'max_depth': 10, 'n_estimators': 50}           0.966667
# 7    {'max_depth': 10, 'n_estimators': 100}           0.966667
# 8    {'max_depth': 10, 'n_estimators': 150}           0.966667
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.966667           0.933333           0.966667                1.0
# 1           0.966667           0.933333           0.966667                1.0
# 2           0.966667           0.933333           0.933333                1.0
# 3           0.966667           0.900000           0.933333                1.0
# 4           0.966667           0.933333           0.966667                1.0
# 5           0.966667           0.933333           0.933333                1.0
# 6           0.966667           0.933333           0.933333                1.0
# 7           0.966667           0.933333           0.966667                1.0
# 8           0.966667           0.933333           0.933333                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.966667        0.021082                1
# 1         0.966667        0.021082                1
# 2         0.960000        0.024944                5
# 3         0.953333        0.033993                9
# 4         0.966667        0.021082                1
# 5         0.960000        0.024944                5
# 6         0.960000        0.024944                5
# 7         0.966667        0.021082                1
# 8         0.960000        0.024944                5

# %%
df[['param_max_depth','param_n_estimators','mean_test_score']]
# Out:
#   param_max_depth  param_n_estimators  mean_test_score
# 0            None                  50         0.966667
# 1            None                 100         0.966667
# 2            None                 150         0.960000
# 3               5                  50         0.953333
# 4               5                 100         0.966667
# 5               5                 150         0.960000
# 6              10                  50         0.960000
# 7              10                 100         0.966667
# 8              10                 150         0.960000

# %%
print(f'Best parameters:',clf.best_params_)
print(f'Best score:',clf.best_score_)
# Out:
# Best parameters: {'max_depth': None, 'n_estimators': 50}
# Best score: 0.9666666666666668

# %% [markdown]
# If we need to try large number of C value, then computational cost will increase

# %% [markdown]
# Use RandomizedSearchCV to reduce number of iterations and with random combination of parameters.

# %%
from sklearn.model_selection import RandomizedSearchCV
rs=RandomizedSearchCV(SVC(gamma='auto'),{
    'C':[1,10,20],
    'kernel':['linear','rbf']
},cv=5,n_iter=2) #randomly try only 2 kernel with 2 C value
rs.fit(iris.data,iris.target)
df=pd.DataFrame(rs.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.001427      0.000297         0.001138        0.000329          rbf
# 1       0.000985      0.000036         0.000817        0.000028       linear
#
#    param_C                        params  split0_test_score  \
# 0       20    {'kernel': 'rbf', 'C': 20}           0.966667
# 1        1  {'kernel': 'linear', 'C': 1}           0.966667
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                1.0           0.900000           0.966667                1.0
# 1                1.0           0.966667           0.966667                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.966667        0.036515                2
# 1         0.980000        0.016330                1

# %%
df[['param_kernel','param_C','mean_test_score']]
# Out:
#   param_kernel  param_C  mean_test_score
# 0          rbf       20         0.966667
# 1       linear        1         0.980000

# %% [markdown]
# Works well in practical life if we do not have too much computational power

# %% [markdown]
# # How about different models with different hyperparameters?

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
model_parameter={
    'SVM':{
        'model':SVC(gamma='auto'),
        'parameter':{
            'C':[1,10,20],
            'kernel':['linear','rbf']
        }
    },
    'Random Forest':{
        'model':RandomForestClassifier(),
        'parameter':{
            'n_estimators':[1,5,10]
        }
    }
}

# %%
score=[]
for model_n,model_p in model_parameter.items():
  clf=GridSearchCV(model_p['model'],model_p['parameter'],cv=5)
  clf.fit(iris.data,iris.target)
  score.append({
      'model':model_n,
      'best_score':clf.best_score_,
      'best_parameter':clf.best_params_
  })
df=pd.DataFrame(score)
df
# Out:
#            model  best_score                best_parameter
# 0            SVM    0.980000  {'C': 1, 'kernel': 'linear'}
# 1  Random Forest    0.966667           {'n_estimators': 5}

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
#
# #Exercise

# %%
from sklearn.model_selection import GridSearchCV
clf=GridSearchCV(SVC(gamma='auto'),{
    'C':[1,10,20],
    'kernel':['rbf','linear']
},cv=5)
clf.fit(iris.data,iris.target)
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.00449991, 0.0021225 , 0.00187964, 0.00158224, 0.00175743,
#         0.00238342]),
#  'std_fit_time': array([8.19318265e-04, 8.84308074e-04, 1.21328533e-04, 5.17726590e-05,
#         4.28388231e-05, 8.04104462e-04]),
#  'mean_score_time': array([0.00523543, 0.00152845, 0.00137239, 0.00120449, 0.00129051,
#         0.00140896]),
#  'std_score_time': array([1.63667695e-03, 5.06276683e-04, 1.24434893e-04, 1.02025325e-05,
#         5.22408567e-05, 1.53602979e-04]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20],
#               mask=[False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear'],
#               mask=[False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'linear'}],
#  'split0_test_score': array([0.96666667, 0.96666667, 0.96666667, 1.        , 0.96666667,
#         1.        ]),
#  'split1_test_score': array([1., 1., 1., 1., 1., 1.]),
#  'split2_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.9       , 0.9       ,
#         0.9       ]),
#  'split3_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.96666667, 0.96666667,
#         0.93333333]),
#  'split4_test_score': array([1., 1., 1., 1., 1., 1.]),
#  'mean_test_score': array([0.98      , 0.98      , 0.98      , 0.97333333, 0.96666667,
#         0.96666667]),
#  'std_test_score': array([0.01632993, 0.01632993, 0.01632993, 0.03887301, 0.03651484,
#         0.0421637 ]),
#  'rank_test_score': array([1, 1, 1, 4, 5, 6], dtype=int32)}

# %%
df=pd.DataFrame(clf.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.004500      0.000819         0.005235        0.001637        1
# 1       0.002122      0.000884         0.001528        0.000506        1
# 2       0.001880      0.000121         0.001372        0.000124       10
# 3       0.001582      0.000052         0.001204        0.000010       10
# 4       0.001757      0.000043         0.001291        0.000052       20
# 5       0.002383      0.000804         0.001409        0.000154       20
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 3       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 4          rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
# 5       linear  {'C': 20, 'kernel': 'linear'}           1.000000
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                1.0           0.966667           0.966667                1.0
# 1                1.0           0.966667           0.966667                1.0
# 2                1.0           0.966667           0.966667                1.0
# 3                1.0           0.900000           0.966667                1.0
# 4                1.0           0.900000           0.966667                1.0
# 5                1.0           0.900000           0.933333                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.980000        0.016330                1
# 1         0.980000        0.016330                1
# 2         0.980000        0.016330                1
# 3         0.973333        0.038873                4
# 4         0.966667        0.036515                5
# 5         0.966667        0.042164                6

# %%
df[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667

# %% [markdown]
# We have supply the first three row of parameter to get the best performance

# %% [markdown]
# Analyze cv_results_: Using the same iris dataset and GridSearchCV from Exercise 1, convert cv_results_ to a DataFrame and display only the columns: param_C, param_kernel, and mean_test_score.

# %%
import pandas as pd
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV

iris = datasets.load_iris()
param_grid = {
    'C': [1, 10, 20],
    'kernel': ['rbf', 'linear']
}

clf = GridSearchCV(svm.SVC(gamma='auto'), param_grid, cv=5)
clf.fit(iris.data, iris.target)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20], 'kernel': ['rbf', 'linear']})

# %%
df=pd.DataFrame(clf.cv_results_)
df[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667

# %%
print('Best:',clf.best_params_)
# Out:
# Best: {'C': 1, 'kernel': 'rbf'}

# %% [markdown]
# RandomizedSearchCV: Use RandomizedSearchCV instead of GridSearchCV with the same parameters, but set n_iter=2 to test only 2 random combinations. Compare the speed difference.

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn import svm, datasets
import pandas as pd
iris = datasets.load_iris()
param_grid = {
    'C': [1, 10, 20],
    'kernel': ['rbf', 'linear']
}

# %%
rs=RandomizedSearchCV(SVC(gamma='auto'),param_grid,cv=5,n_iter=3)
rs.fit(iris.data,iris.target)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(gamma='auto'), n_iter=3,
#                    param_distributions={'C': [1, 10, 20],
#                                         'kernel': ['rbf', 'linear']})

# %%
df=pd.DataFrame(rs.cv_results_)
df[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0       10          rbf         0.980000
# 1       20       linear         0.966667
# 2       20          rbf         0.966667

# %%
print('Best score:',rs.best_score_)
print('Best parameter:',rs.best_params_)
# Out:
# Best score: 0.9800000000000001
# Best parameter: {'kernel': 'rbf', 'C': 10}

# %% [markdown]
# Manual approach vs GridSearchCV: First, manually test different parameters using train_test_split. Then use GridSearchCV with cross-validation. Compare which approach gives more reliable results.

# %%
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split, GridSearchCV

iris = datasets.load_iris()

# Part 1: Manual approach
X_train, X_test, y_train, y_test = train_test_split(
    iris.data, iris.target, test_size=0.3)

# %%
score={}
kernel=['linear','rbf']
c=[10,20,30]
for k in kernel:
  for c_v in c:
    model=SVC(gamma='auto',kernel=k,C=c_v)
    model.fit(X_train,y_train)
    score['Kernel:'+k+" C:"+str(c_v)]=model.score(X_test,y_test)
score
# Out:
# {'Kernel:linear C:10': 0.9777777777777777,
#  'Kernel:linear C:20': 0.9777777777777777,
#  'Kernel:linear C:30': 0.9777777777777777,
#  'Kernel:rbf C:10': 0.9777777777777777,
#  'Kernel:rbf C:20': 0.9777777777777777,
#  'Kernel:rbf C:30': 0.9777777777777777}

# %% [markdown]
# manual score

# %%
model=SVC(kernel='rbf',C=30,gamma='auto')
model.fit(X_train,y_train)
print('Model score(manual):',model.score(X_test,y_test))
# Out:
# Model score(manual): 0.9777777777777777

# %%
clf=GridSearchCV(SVC(gamma='auto'),{
    'C':[1,10,20,30],
    'kernel':['linear','rbf']}
                 ,cv=5)

# %%
clf.fit(iris.data,iris.target)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['linear', 'rbf']})

# %%
df=pd.DataFrame(clf.cv_results_)
df[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1       linear         0.980000
# 1        1          rbf         0.980000
# 2       10       linear         0.973333
# 3       10          rbf         0.980000
# 4       20       linear         0.966667
# 5       20          rbf         0.966667
# 6       30       linear         0.960000
# 7       30          rbf         0.960000

# %%
print('Best parameter:',clf.best_params_)
print('Best score:',clf.best_score_)
# Out:
# Best parameter: {'C': 1, 'kernel': 'linear'}
# Best score: 0.9800000000000001

# %% [markdown]
# For digits dataset in sklearn.dataset, please try following classifiers and find out the one that gives best performance. Also find the optimal parameters for that classifier.

# %%
from sklearn import datasets
digits = datasets.load_digits()

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier

# %%
model_parameter={
    'SVM':{
        'model':SVC(gamma='auto'),
        'parameter':{
            'C':[1,10,20],
            'kernel':['linear','rbf']
        }
    },
    'Random Forest':{
        'model':RandomForestClassifier(),
        'parameter':{
            'n_estimators':[1,5,10]
        }
    },
    'Logistic Regression':{
        'model':LogisticRegression(solver='liblinear'),
        'parameter':{
          'C':[1,5,10]
        }
    },
    'naive_bayes_gaussian':{
        'model':GaussianNB(),
        'parameter':{}

    },
    'naive_bayes_multinomial':{
        'model':MultinomialNB(),
        'parameter':{}
    }
}

# %%
scores=[]
for model_n,model_p in model_parameter.items():
  clf=GridSearchCV(model_p['model'],model_p['parameter'],cv=5)
  clf.fit(digits.data,digits.target)
  scores.append({
      'model':model_n,
      'best_score':clf.best_score_,
      'best_parameter':clf.best_params_
  }
  )
scores
# Out:
# [{'model': 'SVM',
#   'best_score': np.float64(0.9476973073351903),
#   'best_parameter': {'C': 1, 'kernel': 'linear'}},
#  {'model': 'Random Forest',
#   'best_score': np.float64(0.9037480656143609),
#   'best_parameter': {'n_estimators': 10}},
#  {'model': 'Logistic Regression',
#   'best_score': np.float64(0.9221138966264315),
#   'best_parameter': {'C': 1}},
#  {'model': 'naive_bayes_gaussian',
#   'best_score': np.float64(0.8069281956050759),
#   'best_parameter': {}},
#  {'model': 'naive_bayes_multinomial',
#   'best_score': np.float64(0.8703497369235531),
#   'best_parameter': {}}]

# %%
df=pd.DataFrame(scores)
df
# Out:
#                      model  best_score                best_parameter
# 0                      SVM    0.947697  {'C': 1, 'kernel': 'linear'}
# 1            Random Forest    0.903748          {'n_estimators': 10}
# 2      Logistic Regression    0.922114                      {'C': 1}
# 3     naive_bayes_gaussian    0.806928                            {}
# 4  naive_bayes_multinomial    0.870350                            {}

# %% [markdown]
# For me the winner is svm (C=1, kernel=linear) with 94.77% score
